# %%
import sys
import argparse
import os
import torch
from torch.autograd import Variable
from tqdm import tqdm
from time import time
import shutil

# %%
from torch.utils.tensorboard import SummaryWriter

# %%
from configs.config_utils import CONFIG, read_to_dict, mount_external_config
from net_utils.utils import load_dataloader
from adl_scripts.MLP_Regressor import MLP_Regressor

# %%
def parse_args():
    '''PARAMETERS'''
    parser = argparse.ArgumentParser('Pose2Room.')
    parser.add_argument('--config', type=str, default='configs/config_files/p2rnet_train.yaml',
                        help='configure file for training or testing.')
    parser.add_argument('--mode', type=str, default='train', help='train, test or demo.')
    parser.add_argument('--demo_path', type=str, default='demo', help='Please specify the demo path.')
    
    args, unknown = parser.parse_known_args()
    return args

# %%
def train_epoch(dataloader, optimizer, model, loss_func):
    model.train()
    
    device = torch.device("cuda")
    current_loss = 0.0
    for batch_data in dataloader:
        inputs, targets = batch_data['adl_input'], batch_data['adl_output']
        inputs = Variable(inputs.to(device))
        targets = Variable(targets.to(device))
        
        optimizer.zero_grad()
        
        predictions = model(inputs)
        
        loss = loss_func(predictions, targets)
        
        loss.backward()
        optimizer.step()    
        
        current_loss += loss.item()
    
    return current_loss

# %%
def validate_epoch(dataloader, model, loss_func):
    model.eval()
    device = torch.device("cuda")
    current_loss = 0.0
    with torch.no_grad():
        for batch_data in dataloader:
            inputs, targets = batch_data['adl_input'], batch_data['adl_output']
            inputs = inputs.to(device)
            targets = targets.to(device)
            predictions = model(inputs)
            loss = loss_func(predictions, targets)
            
            current_loss += loss.item()
            
    return current_loss

# %%
writer = SummaryWriter()

args = parse_args()
config = read_to_dict('/home/gogebakan/workspace/Pose2Room/configs/config_files/p2rnet_train.yaml')
# initiate device environments
os.environ["CUDA_VISIBLE_DEVICES"] = config['device']['gpu_ids']
from net_utils.utils import initiate_environment, get_sha
config = initiate_environment(config)

# initialize config
cfg = CONFIG(args, config)
cfg.update_config(args.__dict__)
'''Configuration'''
cfg.log_string('Loading configurations.')
cfg.log_string("git:\n  {}\n".format(get_sha()))
cfg.log_string(cfg.config)
cfg.write_config()

'''Mount external config data'''
dataset = 'MLP'
cfg = mount_external_config(cfg)
train_loader = load_dataloader(cfg, mode='train', dataset=dataset).dataloader
validation_loader = load_dataloader(cfg, mode='val', dataset=dataset).dataloader
# Out:
# Not using distributed mode

# %%
device = torch.device("cuda")
epochs = 50
val_epoch = 3
nearest_k_frames = 10
input_size = 8 + 2*nearest_k_frames*256
output_size = 1024
layer_sizes = [2048]
model = MLP_Regressor(input_size=input_size, output_size=output_size, layer_sizes=layer_sizes)

model = model.to(device)
model.train()

l2_loss = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

best_loss = 10*5
patience = 2
early_stop_counter = 0

for epoch in range(epochs):
    #train
    start = time()
    train_loss = train_epoch(train_loader, optimizer, model, l2_loss)
    end = time()
    epoch_time = end-start
    writer.add_scalar("Loss/train_epoch", train_loss, epoch)
    
    # validation
    if epoch % val_epoch == 0:
        validation_loss = validate_epoch(validation_loader, model, l2_loss)
        print(f'Epoch {epoch}\tTraining loss:\t{train_loss:.5f}\t{epoch_time:.2f}s\tValidation loss:\t{validation_loss:.5f}\t{epoch_time:.2f}s')
        
        writer.add_scalar("Loss/validation_epoch", validation_loss, epoch)
        if validation_loss > best_loss:
            early_stop_counter += 1
            if early_stop_counter == patience:
                print(f'Early stopping with best validation_loss: {best_loss}')
                break
        else:
            best_loss = validation_loss
            early_stop_counter = 0
            torch.save(model.state_dict(), f'saved_models/checkpoint{len(layer_sizes)}.pt')
                
    else:
        print(f'Epoch {epoch}\tTraining loss:\t{train_loss:.5f}\t{epoch_time:.2f}s')
    
writer.flush()
writer.close()
# Out:
# Epoch 0	Training loss:	56.07395	2.37s	Validation loss:	32.59067	2.37s
# Epoch 1	Training loss:	6.78838	1.82s
# Epoch 2	Training loss:	5.92624	1.73s
# Epoch 3	Training loss:	5.54696	1.80s	Validation loss:	21.91470	1.80s
# Epoch 4	Training loss:	5.08473	1.88s
# Epoch 5	Training loss:	4.60434	1.79s
# Epoch 6	Training loss:	4.23230	1.81s	Validation loss:	16.90760	1.81s
# Epoch 7	Training loss:	3.98793	2.03s
# Epoch 8	Training loss:	3.79230	1.87s
# Epoch 9	Training loss:	3.60287	1.82s	Validation loss:	14.72249	1.82s
# Epoch 10	Training loss:	3.43609	1.84s
# Epoch 11	Training loss:	3.29353	1.99s
# Epoch 12	Training loss:	3.18241	1.76s	Validation loss:	13.37101	1.76s
# Epoch 13	Training loss:	3.05958	1.78s
# Epoch 14	Training loss:	2.97569	1.82s
# Epoch 15	Training loss:	2.89772	1.73s	Validation loss:	12.50033	1.73s
# Epoch 16	Training loss:	2.82694	1.86s
# Epoch 17	Training loss:	2.74301	1.79s
# Epoch 18	Training loss:	2.66295	1.85s	Validation loss:	11.86133	1.85s
# Epoch 19	Training loss:	2.59493	1.80s
# Epoch 20	Training loss:	2.53989	1.83s
# Epoch 21	Training loss:	2.49000	1.75s	Validation loss:	11.16858	1.75s
# Epoch 22	Training loss:	2.42017	1.87s
# Epoch 23	Training loss:	2.38634	1.98s
# Epoch 24	Training loss:	2.34462	1.86s	Validation loss:	10.80791	1.86s
# Epoch 25	Training loss:	2.31770	2.03s
# Epoch 26	Training loss:	2.27612	2.20s
# Epoch 27	Training loss:	2.24354	1.85s	Validation loss:	10.53512	1.85s
# Epoch 28	Training loss:	2.21181	1.85s
# Epoch 29	Training loss:	2.16496	1.86s
# Epoch 30	Training loss:	2.13873	1.78s	Validation loss:	10.24826	1.78s
# Epoch 31	Training loss:	2.11563	1.78s
# Epoch 32	Training loss:	2.08519	1.91s
# Epoch 33	Training loss:	2.07423	1.78s	Validation loss:	10.09394	1.78s
# Epoch 34	Training loss:	2.04047	2.30s
# Epoch 35	Training loss:	2.02465	1.84s
# Epoch 36	Training loss:	1.98705	1.81s	Validation loss:	9.88142	1.81s
# Epoch 37	Training loss:	1.97316	1.89s
# Epoch 38	Training loss:	1.96333	2.23s
# Epoch 39	Training loss:	1.93045	1.82s	Validation loss:	9.86954	1.82s
# Epoch 40	Training loss:	1.90725	1.88s
# Epoch 41	Training loss:	1.88363	2.16s
# Epoch 42	Training loss:	1.88953	2.37s	Validation loss:	9.67913	2.37s
# Epoch 43	Training loss:	1.85046	1.80s
# Epoch 44	Training loss:	1.86810	1.83s
# Epoch 45	Training loss:	1.82145	1.83s	Validation loss:	9.52578	1.83s
# Epoch 46	Training loss:	1.80376	1.79s
# Epoch 47	Training loss:	1.78728	1.88s
# Epoch 48	Training loss:	1.79745	1.82s	Validation loss:	9.45472	1.82s
# Epoch 49	Training loss:	1.79701	1.79s
